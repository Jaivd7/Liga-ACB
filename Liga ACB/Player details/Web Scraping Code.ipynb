# %%
import pandas as pd



dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/763/2020',header=0)
for df1 in dfs:
    print(df1)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/659/2019',header=0)
for df2 in dfs:
    print(df2)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/515/2018',header=0)
for df3 in dfs:
    print(df3)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/426/2017',header=0)
for df4 in dfs:
    print(df4)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/344/2016',header=0)
for df5 in dfs:
    print(df5)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/players/259/2015',header=0)
for df6 in dfs:
    print(df6)
    
df1.to_csv('2019-2020.csv')
df2.to_csv('2018-2019.csv')
df3.to_csv('2017-2018.csv')
df4.to_csv('2016-2017.csv')
df5.to_csv('2015-2016.csv')
df6.to_csv('2014-2015.csv')
# Out:
#              Player Pos   HT   WT                     Team     Birth City  \
# 0    Alberto Abalde  GF  6-7  215          Valencia Basket       A Coruna
# 1      Alex Abrines  GF  6-6  190       FC Barcelona Lassa          Palma
# 2        Josh Adams   G  6-2  190           Unicaja Malaga    Parker (CO)
# 3     Pablo Aguilar  PF  6-8  235       Iberostar Tenerife        Granada
# 4     Pablo Almazan  SF  6-5  190  Real Betis Energia Plus        Granada
# ..              ...  ..  ...  ...                      ...            ...
# 304     Tony Wroten  PG  6-6  205  Divina Seguros Joventut    Renton (WA)
# 305  Santiago Yusta  SF  6-6  183       Iberostar Tenerife         Madrid
# 306   Arturs Zagars  PG  6-3  172  Divina Seguros Joventut           Riga
# 307   Nick Zeisloft   G  6-4  185       Iberostar Tenerife  LaGrange (IL)
# 308     Nikos Zisis  PG  6-5  207  Divina Seguros Joventut   Thessaloniki
#
#                   Draft Status    Nationality
# ...
