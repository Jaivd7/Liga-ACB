# %%
import pandas as pd

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2020/Advanced_Stats/Team_Totals',header=0)
for df1 in dfs:
    print(df1)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2019/Advanced_Stats/Team_Totals',header=0)
for df2 in dfs:
    print(df2)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2018/Advanced_Stats/Team_Totals',header=0)
for df3 in dfs:
    print(df3)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2017/Advanced_Stats/Team_Totals',header=0)
for df4 in dfs:
    print(df4)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2016/Advanced_Stats/Team_Totals',header=0)
for df5 in dfs:
    print(df5)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/team-stats/2015/Advanced_Stats/Team_Totals',header=0)
for df6 in dfs:
    print(df6)
    
df1.to_csv('2019-2020.csv')
df2.to_csv('2018-2019.csv')
df3.to_csv('2017-2018.csv')
df4.to_csv('2016-2017.csv')
df5.to_csv('2015-2016.csv')
df6.to_csv('2014-2015.csv')
# Out:
#      #                               Team    TS%   eFG%  Total S%  ORB%  DRB%  \
# 0    1                        Real Madrid  0.597  0.557     164.2  28.0  71.8
# 1    2                 FC Barcelona Lassa  0.604  0.553     161.8  33.8  73.2
# 2    3                    Valencia Basket  0.594  0.552     166.3  32.2  71.1
# 3    4                Tecnyconta Zaragoza  0.562  0.528     155.4  29.9  69.6
# 4    5                 Iberostar Tenerife  0.591  0.551     163.1  29.2  71.7
# 5    6                   MoraBanc Andorra  0.564  0.524     153.0  29.7  70.4
# 6    7  KIROLBET Baskonia Vitoria-Gasteiz  0.578  0.543     155.8  33.2  73.4
# 7    8                     Unicaja Malaga  0.554  0.505     155.7  30.4  71.0
# 8    9              RETAbet Bilbao Basket  0.569  0.533     158.0  28.3  67.2
# 9   10             Herbalife Gran Canaria  0.571  0.540     156.4  28.8  74.6
# 10  11      San Pablo Inmobiliaria Burgos  0.553  0.532     146.3  29.7  70.7
# ...
