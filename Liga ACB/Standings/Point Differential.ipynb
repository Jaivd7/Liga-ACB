# %%
import pandas as pd

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/763/2020',header=0)
for df1 in dfs:
    print(df1)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/659/2019',header=0)
for df2 in dfs:
    print(df2)

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/515/2018',header=0)
for df3 in dfs:
    print(df3)

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/426/2017',header=0)
for df4 in dfs:
    print(df4)

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/344/2016',header=0)
for df5 in dfs:
    print(df5)
 
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/standings/259/2015',header=0)
for df6 in dfs:
    print(df6)
# Out:
#      #                               Team   W   L    PCT    GB  L10 STRK  \
# 0    1                 FC Barcelona Lassa  19   4  0.826   0.0  9-1  W 6
# 1    2                        Real Madrid  18   5  0.783   1.0  7-3  W 3
# 2    3                Tecnyconta Zaragoza  16   7  0.696   3.0  6-4  L 1
# 3    4                 Iberostar Tenerife  14   8  0.636   4.5  7-3  L 1
# 4    5              RETAbet Bilbao Basket  14   9  0.609   5.0  8-2  W 1
# 5    6                   MoraBanc Andorra  13  10  0.565   6.0  6-4  W 1
# 6    7                    Valencia Basket  12  11  0.522   7.0  5-5  L 1
# 7    8  KIROLBET Baskonia Vitoria-Gasteiz  12  11  0.522   7.0  5-5  W 3
# 8    9      San Pablo Inmobiliaria Burgos  12  11  0.522   7.0  5-5  W 1
# 9   10                     Unicaja Malaga  12  11  0.522   7.0  5-5  W 1
# 10  11             Herbalife Gran Canaria  11  11  0.500   7.5  5-5  W 2
# 11  12            Divina Seguros Joventut   9  14  0.391  10.0  2-8  L 3
# ...

# %%
seed7=[]
seed8=[]
def a(x):
    data=x.iloc[0:18]['DIFF']
    i=0
    y=[]
    while i!=18:
        y.append(data[i])
        i=i+1
    y.sort(reverse=True)
    seed7.append(y[6])
    seed8.append(y[7])
    return;

def b(x):
    data=x.iloc[0:17]['DIFF']
    i=0
    y=[]
    while i!=17:
        y.append(data[i])
        i=i+1
    y.sort(reverse=True)
    seed7.append(y[6])
    seed8.append(y[7])
    return;


a(df1);
a(df2);
a(df3);
a(df5);
b(df4);
b(df6);
# Out:
# 2020 Average is :
# [10.0, 8.4, 6.8, 4.4, 3.0, 2.2, 1.7, 1.1, -0.1, -0.5, -1.5, -3.5, -3.6, -4.1, -4.5, -6.0, -7.0, -7.2]
# [1.7]
# 2019 Average is :
# [11.1, 10.5, 10.2, 3.5, 2.0, 1.8, 0.9, 0.6, -0.7, -1.3, -1.9, -2.2, -3.6, -5.0, -5.2, -6.9, -6.9, -7.3]
# [1.7, 0.9]
# 2018 Average is :
# [11.0, 10.0, 8.1, 6.7, 4.3, 3.2, 2.1, 2.0, 1.1, -1.0, -2.7, -3.3, -3.6, -4.8, -5.5, -6.6, -7.4, -13.8]
# [1.7, 0.9, 2.1]
# 2016 Average is :
# [13.6, 13.3, 9.7, 8.4, 3.8, 3.3, 0.6, -1.7, -1.8, -2.3, -2.4, -2.8, -3.6, -4.4, -6.2, -6.6, -8.4, -12.2]
# [1.7, 0.9, 2.1, 0.6]
# 2017 Average is :
# [9.5, 8.5, 7.9, 7.6, 6.4, 5.9, 5.2, -0.3, -1.8, -2.4, -3.2, -3.2, -5.5, -5.9, -7.8, -7.9, -12.8]
# 2015 Average is :
# [10.3, 7.8, 4.9, 4.5, 4.2, 1.3, 1.0, 0.8, 0.1, -1.1, -1.7, -1.9, -2.0, -3.1, -5.4, -6.0, -7.0]

# %%
def Average(lst): 
    print(sum(lst) / len(lst))
    return;

print ('7 average is :')
Average(seed7);
print ('8 average is :')
Average(seed8);
# Out:
# 7 average is :
# 1.9166666666666667
# 8 average is :
# 0.4166666666666667
